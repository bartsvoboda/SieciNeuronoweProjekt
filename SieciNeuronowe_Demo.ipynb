# %%
#Pobieranie wytrenowanego modelu
# !pip install gdown
# !gdown https://drive.google.com/uc?id=1YFZ072MF_Qol_-p2XJF4GFjcGLzYIPsR
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1YFZ072MF_Qol_-p2XJF4GFjcGLzYIPsR
# To: /content/fullset_batch2_epochs_12.zip
# 100% 231M/231M [00:03<00:00, 61.9MB/s]

# %%
# !unzip fullset_batch2_epochs_12.zip
# %rm fullset_batch2_epochs_12.zip
# Out:
# Archive:  fullset_batch2_epochs_12.zip
#    creating: fullset_batch2_epochs_12/
#   inflating: fullset_batch2_epochs_12/b2_e12.png
#   inflating: fullset_batch2_epochs_12/confusion_matrix.png
#   inflating: fullset_batch2_epochs_12/events.out.tfevents.1639863724.DESKTOP-1JF27MR.12712.0
#   inflating: fullset_batch2_epochs_12/F1_curve.png
#   inflating: fullset_batch2_epochs_12/hyp.yaml
#   inflating: fullset_batch2_epochs_12/opt.yaml
#   inflating: fullset_batch2_epochs_12/PR_curve.png
#   inflating: fullset_batch2_epochs_12/P_curve.png
#   inflating: fullset_batch2_epochs_12/results.csv
#   inflating: fullset_batch2_epochs_12/R_curve.png
#   inflating: fullset_batch2_epochs_12/train_batch0.jpg
#   inflating: fullset_batch2_epochs_12/train_batch1.jpg
#   inflating: fullset_batch2_epochs_12/train_batch2.jpg
#   inflating: fullset_batch2_epochs_12/val_batch0_labels.jpg
#   inflating: fullset_batch2_epochs_12/val_batch0_pred.jpg
# ...

# %%
# !git clone https://github.com/ultralytics/yolov3  # clone
# %cd yolov3
# %pip install -qr requirements.txt  # install
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 9960, done.
# remote: Total 9960 (delta 0), reused 0 (delta 0), pack-reused 9960
# Receiving objects: 100% (9960/9960), 9.31 MiB | 8.83 MiB/s, done.
# Resolving deltas: 100% (6717/6717), done.
# /content/yolov3
#      |████████████████████████████████| 596 kB 4.2 MB/s
#      |████████████████████████████████| 1.7 MB 41.7 MB/s
#      |████████████████████████████████| 142 kB 45.6 MB/s
#      |████████████████████████████████| 97 kB 6.3 MB/s
#      |████████████████████████████████| 180 kB 48.2 MB/s
#      |████████████████████████████████| 63 kB 1.5 MB/s
# ...

# %%
import torch
from yolov3 import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv3 🚀 v9.6.0-6-g0f80f2f torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅

# %%
# !mv ../fullset_batch2_epochs_12/weights/best.pt ./custom_weights.pt

# %% [markdown]
# ## 2. Testowanie modelu yolov3 w zadaniu detekcji pojazdów

# %% [markdown]
# ### 2.0 Pobranie przygotowanych danych z dysku

# %% [markdown]
# Zdjecia

# %%
# !gdown https://drive.google.com/uc?id=11Dmr-sVuE5faok1hWxx5e_-FzOI0bm-3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11Dmr-sVuE5faok1hWxx5e_-FzOI0bm-3
# To: /content/yolov3/Zdjecia.zip
# 100% 46.3M/46.3M [00:01<00:00, 45.6MB/s]

# %%
# !unzip Zdjecia.zip
# Out:
# Archive:  Zdjecia.zip
#   inflating: Zdjecia/london_night_2.PNG
#   inflating: Zdjecia/night2.PNG
#   inflating: Zdjecia/chicago_night_3.PNG
#   inflating: Zdjecia/chicago_night_2.PNG
#   inflating: Zdjecia/london_night_1.PNG
#   inflating: Zdjecia/chicago_day_1.PNG
#   inflating: Zdjecia/chicago_day_4.PNG
#   inflating: Zdjecia/london_day_2.PNG
#   inflating: Zdjecia/night1.PNG
#   inflating: Zdjecia/london_night_4.PNG
#   inflating: Zdjecia/chicago_night_1.PNG
#   inflating: Zdjecia/night5.PNG
#   inflating: Zdjecia/london_day_1.PNG
#   inflating: Zdjecia/night3.PNG
#   inflating: Zdjecia/london_night_3.PNG
#   inflating: Zdjecia/london_day_5.PNG
#   inflating: Zdjecia/chicago_day_3.PNG
#   inflating: Zdjecia/chicago_day_5.PNG
#   inflating: Zdjecia/chicago_night_5.PNG
#   inflating: Zdjecia/night4.PNG
#   inflating: Zdjecia/london_night_5.PNG
#   inflating: Zdjecia/london_day_4.PNG
#   inflating: Zdjecia/chicago_day_2.PNG
#   inflating: Zdjecia/london_day_3.PNG
# ...

# %% [markdown]
# Wideo

# %%
# !gdown https://drive.google.com/uc?id=1v65aqHrkFhwHv-qisevSvVqUSHPZH6qD
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1v65aqHrkFhwHv-qisevSvVqUSHPZH6qD
# To: /content/yolov3/Wideo.zip
# 100% 11.3M/11.3M [00:00<00:00, 22.0MB/s]

# %%
# !unzip Wideo.zip
# Out:
# Archive:  Wideo.zip
#   inflating: Wideo/Seoul_night.mp4
#   inflating: Wideo/NYork_day.mp4

# %% [markdown]
# ### 2.1 Zdjęcia

# %% [markdown]
# Przed Detekcją

# %%
display.Image("Zdjecia/london_day_1.PNG")

# %% [markdown]
# Detekcja

# %%
# !python detect.py --weights custom_weights.pt --conf 0.25 --source Zdjecia/
# Out:
# ...
# detect: weights=['custom_weights.pt'], source=Zdjecia/, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-6-g0f80f2f torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61497430 parameters, 0 gradients, 154.7 GFLOPs
# image 1/30 /content/yolov3/Zdjecia/chicago_day_1.PNG: 352x640 8 items, Done. (0.114s)
# image 2/30 /content/yolov3/Zdjecia/chicago_day_2.PNG: 352x640 5 items, Done. (0.105s)
# image 3/30 /content/yolov3/Zdjecia/chicago_day_3.PNG: 352x640 3 items, Done. (0.102s)
# image 4/30 /content/yolov3/Zdjecia/chicago_day_4.PNG: 352x640 5 items, Done. (0.100s)
# ...

# %% [markdown]
# Po Detekcji

# %%
display.Image("runs/detect/exp/london_day_1.PNG")

# %% [markdown]
# ### 2.2 Wideo

# %%
# !python detect.py --weights custom_weights.pt --conf 0.25 --source ./Wideo/Seoul_night.mp4
# Out:
# detect: weights=['custom_weights.pt'], source=./Wideo/Seoul_night.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-6-g0f80f2f torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61497430 parameters, 0 gradients, 154.7 GFLOPs
# video 1/1 (1/961) /content/yolov3/Wideo/Seoul_night.mp4: 384x640 Done. (0.114s)
# video 1/1 (2/961) /content/yolov3/Wideo/Seoul_night.mp4: 384x640 Done. (0.103s)
# video 1/1 (3/961) /content/yolov3/Wideo/Seoul_night.mp4: 384x640 Done. (0.098s)
# video 1/1 (4/961) /content/yolov3/Wideo/Seoul_night.mp4: 384x640 Done. (0.094s)
# ...

# %%
# !python detect.py --weights custom_weights.pt --conf 0.25 --source ./Wideo/NYork_day.mp4
# Out:
# detect: weights=['custom_weights.pt'], source=./Wideo/NYork_day.mp4, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv3 🚀 v9.6.0-6-g0f80f2f torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 261 layers, 61497430 parameters, 0 gradients, 154.7 GFLOPs
# video 1/1 (1/1562) /content/yolov3/Wideo/NYork_day.mp4: 384x640 1 item, Done. (0.125s)
# video 1/1 (2/1562) /content/yolov3/Wideo/NYork_day.mp4: 384x640 1 item, Done. (0.114s)
# video 1/1 (3/1562) /content/yolov3/Wideo/NYork_day.mp4: 384x640 1 item, Done. (0.106s)
# video 1/1 (4/1562) /content/yolov3/Wideo/NYork_day.mp4: 384x640 1 item, Done. (0.099s)
# ...
